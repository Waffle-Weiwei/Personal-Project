# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
raw_df = pd.read_csv("/content/drive/MyDrive/Data Science/Heights_Raw_Data.csv")
raw_df.head()
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Sex                                         1050 non-null   object
#  1   Year                                        1050 non-null   int64
#  2   Age group                                   1050 non-null   int64
#  3   Mean height                                 1050 non-null   float64
#  4   Mean height lower 95% uncertainty interval  1050 non-null   float64
#  5   Mean height upper 95% uncertainty interval  1050 non-null   float64
#  6   Mean height standard error                  1050 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 57.6+ KB

# %% [markdown]
# There are no missing values.

# %%
raw_df['Mean height'].hist()
# Out:
# <Axes: >

# %%
girls12_df = raw_df[(raw_df['Sex'] == 'Girls') & (raw_df['Age group'] == 12)]
girls12_df.shape
girls12_df['Mean height'].hist()
girls12_df['Mean height'].describe()
# Out:
# count     35.000000
# mean     146.760886
# std        0.887294
# min      145.797559
# 25%      145.949715
# 50%      146.561456
# 75%      147.312646
# max      148.711637
# Name: Mean height, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(girls12_df['Year'], girls12_df['Mean height'])

# %% [markdown]
# The scatterplot suggests that mean hieght may increase over time.

# %%
girls12_df.isnull().sum()
# Out:
# Sex                                           0
# Year                                          0
# Age group                                     0
# Mean height                                   0
# Mean height lower 95% uncertainty interval    0
# Mean height upper 95% uncertainty interval    0
# Mean height standard error                    0
# dtype: int64

# %% [markdown]
# -Raw file preserved as Height_Raw_Data.csv
#
# -filtered to Sex=='Girls' and Age group == 12
#
# -No missing values found, no rows dropped.

# %% [markdown]
# My planned main test is a linear regression of Mean height on Year, and one assumption I'll check is approximate linearity.

# %%
girls12_df.to_csv('Heights_Girls12_Cleaned.csv', index=False)
